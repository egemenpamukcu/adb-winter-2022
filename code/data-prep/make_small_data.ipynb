# %% [markdown]
# # Make Small Data
# Code in this notebook collects merged_data.csv, filters the variables that we chose, imputes missing data using earlier years, and calculates missingness by country and indicator. Produces small_data.csv, small_data_imputed.csv, indicator_coverage.csv, and country_coverage.csv

# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('data/merged_data.csv')
variables = pd.read_csv('data/variables.csv')

# %%
# 0s vs missingness for migration
cols = ['iso', 'country_name', 'year']

migration = ['ims_both_sex', 'estimated_refugee_stock_incl_asylum_seekers_both_sexes', 'disaster_stock_displacementr_raw', 'conflict_stock_displacement_raw']

climate = ['CCH', 'AIR', 'hdi_value']

# no CPI corruption data, replaced with WWGI corruption
governance = ['value.Rule of Law: Estimate', 'value.Government Effectiveness: Estimate', 'value.Control of Corruption: Estimate']

ys = ['P1: State Legitimacy', 'D_avg', 'D12']

controls = ['GDP per capita (constant 2015 US$)', 'value.Gini index (World Bank estimate)']

all_cols = cols + migration + climate + governance + controls + ys

# %%
small_df = df[all_cols]
small_vars = variables[variables.variable.isin(all_cols)]
small_vars
# Out:
#                                 file_name data_source  \
# 0                          wwgi_clean.csv        WWGI
# 1                          wwgi_clean.csv        WWGI
# 4                          wwgi_clean.csv        WWGI
# 8    IDMC_Conflict and Disaster Total.csv        IDMC
# 14   IDMC_Conflict and Disaster Total.csv        IDMC
# 16         UN HDI, Environment Pillar.csv      UN_HDI
# 19                                epi.csv    Yale EPI
# 25                                epi.csv    Yale EPI
# 71                       UNDESA_clean.csv      UNDESA
# 81                       UNDESA_clean.csv      UNDESA
# 93                                fsi.csv         FSI
# 99                           wb_macro.csv  World Bank
# 100                          wb_macro.csv  World Bank
# 121                     ADB_CPA_clean.csv     ADB_CPA
# 126                     ADB_CPA_clean.csv     ADB_CPA
#
#                                               variable  min_year  max_year
# 0                value.Control of Corruption: Estimate    2011.0    2020.0
# 1             value.Government Effectiveness: Estimate    2011.0    2020.0
# 4                          value.Rule of Law: Estimate    2011.0    2020.0
# 8                      conflict_stock_displacement_raw    2008.0    2020.0
# 14                    disaster_stock_displacementr_raw    2008.0    2020.0
# 16                                           hdi_value    2010.0    2019.0
# 19                                                 AIR    2010.0    2020.0
# 25                                                 CCH    2010.0    2020.0
# 71                                        ims_both_sex    2020.0    2020.0
# 81   estimated_refugee_stock_incl_asylum_seekers_bo...    2020.0    2020.0
# 93                                P1: State Legitimacy    2012.0    2021.0
# 99              value.Gini index (World Bank estimate)    2001.0    2019.0
# 100                 GDP per capita (constant 2015 US$)    2001.0    2020.0
# 121                                                D12    2010.0    2020.0
# 126                                              D_avg    2010.0    2020.0

# %% [markdown]
# ## Create a DataFrame with the latest data available for each indicator

# %%
dfs = []
flag = True
for year in small_vars.max_year.unique():
    var_list = list(small_vars[small_vars['max_year']==year].variable)
    c_df = small_df.loc[small_df.year==year, cols + var_list]
    c_df.drop(['year'], inplace=True, axis=1)
    if flag:
        first_df = c_df
        flag = False
        continue
    first_df = first_df.merge(c_df, how='outer', on=['iso', 'country_name'])
first_df.reset_index(drop=True, inplace=True)
first_df.head()
# Out:
#    iso country_name  value.Control of Corruption: Estimate  \
# 0  NPL        Nepal                              -0.577751
# 1  AFG  Afghanistan                              -1.475405
# 2  ARM      Armenia                               0.031597
# 3  AUS    Australia                               1.665165
# 4  AZE   Azerbaijan                              -1.048197
#
#    value.Government Effectiveness: Estimate  value.Rule of Law: Estimate  \
# 0                                 -0.944426                    -0.490970
# 1                                 -1.523115                    -1.807697
# 2                                 -0.124236                    -0.083223
# 3                                  1.619163                     1.651188
# 4                                 -0.170233                    -0.691043
#
#    conflict_stock_displacement_raw  disaster_stock_displacementr_raw   AIR  \
# 0                              0.0                           28000.0  14.6
# 1                        3546858.0                         1117000.0  17.7
# 2                            800.0                            2700.0  36.3
# 3                              0.0                            5100.0  98.2
# 4                         735455.0                               0.0  24.9
#
#     CCH  ims_both_sex  estimated_refugee_stock_incl_asylum_seekers_both_sexes  \
# 0  23.7      487564.0                                            19634.0
# 1  22.2      144098.0                                            72479.0
# 2  46.7      190349.0                                            18158.0
# 3  70.4     7685860.0                                           154129.0
# 4  48.6      252228.0                                             1288.0
#
#    GDP per capita (constant 2015 US$)  D12  D_avg hdi_value  \
# 0                         1028.463277  3.5    3.9     0.602
# 1                          529.741210  1.5    2.8     0.511
# 2                         4021.046264  NaN    NaN     0.776
# 3                        58043.580660  NaN    NaN     0.944
# 4                         5083.381639  NaN    NaN     0.756
#
#    value.Gini index (World Bank estimate)  P1: State Legitimacy
# 0                                     NaN                   6.4
# 1                                     NaN                   8.7
# 2                                    29.9                   6.9
# 3                                     NaN                   0.5
# 4                                     NaN                   9.1

# %%
df.loc[df.iso=='AUS', ['year', 'value.Gini index (World Bank estimate)']]
# Out:
#      year  value.Gini index (World Bank estimate)
# 3    2011                                     NaN
# 50   2012                                     NaN
# 97   2013                                     NaN
# 144  2014                                    34.4
# 191  2015                                     NaN
# 238  2016                                     NaN
# 285  2017                                     NaN
# 332  2018                                     NaN
# 379  2019                                     NaN
# 426  2020                                     NaN
# 472  2010                                    34.7
# 541  2021                                     NaN

# %% [markdown]
# ## Impute missing data with the most recent available data

# %%
sorted_df = df.sort_values('year', ascending=False)

imputed_df = first_df.copy(deep=True)
for i, row in imputed_df.iterrows():
    country = row['iso']
    for k, v in row.items():
        if pd.isna(v) and k not in ys:
            try: 
                filling = df.loc[(df.iso==country) & (~df[k].isna()), [k]].iat[0, 0]
                recent_year = df.loc[(df.iso==country) & (~df[k].isna()), ['year']].iat[0, 0]
                imputed_df.at[i, k] = filling
                print(f"imputed {country}: {k} with {filling} ({recent_year})")
            except IndexError:
                continue
# Out:
# imputed NPL: value.Gini index (World Bank estimate) with 32.8 (2010)
# imputed AUS: value.Gini index (World Bank estimate) with 34.4 (2014)
# imputed BGD: value.Gini index (World Bank estimate) with 32.4 (2016)
# imputed BTN: value.Gini index (World Bank estimate) with 38.8 (2012)
# imputed BRN: conflict_stock_displacement_raw with 0.0 (2014)
# imputed BRN: disaster_stock_displacementr_raw with 0.0 (2014)
# imputed COK: value.Control of Corruption: Estimate with -0.2318449 (2011)
# imputed COK: value.Government Effectiveness: Estimate with -0.9730545 (2011)
# imputed COK: value.Rule of Law: Estimate with -0.8820833 (2011)
# imputed COK: conflict_stock_displacement_raw with 0.0 (2016)
# imputed COK: disaster_stock_displacementr_raw with 0.0 (2016)
# imputed COK: AIR with 100.0 (2012)
# imputed FSM: conflict_stock_displacement_raw with 0.0 (2012)
# imputed FSM: disaster_stock_displacementr_raw with 0.0 (2012)
# imputed FSM: value.Gini index (World Bank estimate) with 40.1 (2013)
# imputed FJI: value.Gini index (World Bank estimate) with 36.7 (2013)
# imputed HKG: AIR with 32.38 (2012)
# imputed HKG: CCH with 36.1 (2012)
# imputed IND: value.Gini index (World Bank estimate) with 35.7 (2011)
# imputed JPN: value.Gini index (World Bank estimate) with 32.9 (2013)
# imputed KAZ: value.Gini index (World Bank estimate) with 28.0 (2011)
# imputed KIR: conflict_stock_displacement_raw with 0.0 (2015)
# imputed KIR: disaster_stock_displacementr_raw with 0.0 (2015)
# imputed LAO: value.Gini index (World Bank estimate) with 36.0 (2012)
# imputed MYS: value.Gini index (World Bank estimate) with 43.9 (2011)
# imputed MDV: conflict_stock_displacement_raw with 0.0 (2017)
# imputed MDV: disaster_stock_displacementr_raw with 0.0 (2017)
# imputed MDV: value.Gini index (World Bank estimate) with 31.3 (2016)
# imputed MHL: conflict_stock_displacement_raw with 0.0 (2014)
# imputed MHL: disaster_stock_displacementr_raw with 0.0 (2014)
# imputed MNG: value.Gini index (World Bank estimate) with 33.9 (2011)
# imputed MMR: value.Gini index (World Bank estimate) with 38.1 (2015)
# imputed NRU: AIR with 100.0 (2012)
# imputed NRU: value.Gini index (World Bank estimate) with 34.8 (2012)
# imputed NIU: value.Control of Corruption: Estimate with -0.4412377000000001 (2011)
# imputed NIU: value.Government Effectiveness: Estimate with -0.9730545 (2011)
# imputed NIU: value.Rule of Law: Estimate with -0.7358481 (2011)
# imputed NIU: AIR with 100.0 (2012)
# imputed PAK: value.Gini index (World Bank estimate) with 30.9 (2011)
# imputed PLW: conflict_stock_displacement_raw with 0.0 (2012)
# imputed PLW: disaster_stock_displacementr_raw with 0.0 (2012)
# imputed PLW: AIR with 100.0 (2012)
# imputed PLW: CCH with 1.02 (2014)
# imputed CHN: value.Gini index (World Bank estimate) with 42.4 (2011)
# imputed PHL: value.Gini index (World Bank estimate) with 46.5 (2012)
# imputed KOR: value.Gini index (World Bank estimate) with 31.6 (2012)
# imputed WSM: value.Gini index (World Bank estimate) with 38.7 (2013)
# imputed SLB: value.Gini index (World Bank estimate) with 37.1 (2012)
# imputed LKA: value.Gini index (World Bank estimate) with 38.7 (2012)
# imputed TJK: value.Gini index (World Bank estimate) with 34.0 (2015)
# imputed TLS: value.Gini index (World Bank estimate) with 28.7 (2014)
# imputed TON: value.Gini index (World Bank estimate) with 37.6 (2015)
# imputed TKM: conflict_stock_displacement_raw with 4000.0 (2011)
# imputed TKM: disaster_stock_displacementr_raw with 0.0 (2011)
# imputed TKM: GDP per capita (constant 2015 US$) with 4810.896166 (2011)
# imputed TUV: AIR with 20.02 (2012)
# imputed TUV: value.Gini index (World Bank estimate) with 39.1 (2010)
# imputed VUT: value.Gini index (World Bank estimate) with 37.6 (2010)
# imputed VNM: value.Gini index (World Bank estimate) with 35.6 (2012)

# %% [markdown]
# ## Get Coverage by Country

# %%
missing_df = ~(imputed_df.iloc[:, 2:].isna())
missing_df.insert(0, 'country_name', imputed_df['country_name'])
missing_df.insert(0, 'iso', imputed_df['iso'])
missingness = missing_df.iloc[:, 2:].sum(axis=1) / missing_df.iloc[:, 2:].shape[1]
missing_df.insert(2, 'completeness', missingness)
missing_df.sort_values(by='completeness', inplace=True)
missing_df
# Out:
#     iso                      country_name  completeness  \
# 48  TWN         Taiwan, Province of China      0.266667
# 28  NIU                              Niue      0.333333
# 47  SGP                         Singapore      0.400000
# 9   COK                      Cook Islands      0.466667
# 43  TUV                            Tuvalu      0.666667
# 26  NRU                             Nauru      0.666667
# 7   BRN                 Brunei Darussalam      0.733333
# 18  KIR                          Kiribati      0.733333
# 13  HKG                         Hong Kong      0.733333
# 30  PLW                             Palau      0.800000
# 27  NZL                       New Zealand      0.800000
# 23  MHL                  Marshall Islands      0.800000
# 42  TKM                      Turkmenistan      0.800000
# 4   AZE                        Azerbaijan      0.800000
# 46  VNM                          Viet Nam      0.800000
# 39  THA                          Thailand      0.866667
# 37  LKA                         Sri Lanka      0.866667
# 34  KOR                Korea, Republic of      0.866667
# 33  PHL                       Philippines      0.866667
# 32  CHN                             China      0.866667
# 2   ARM                           Armenia      0.866667
# 3   AUS                         Australia      0.866667
# 12  GEO                           Georgia      0.866667
# 11  FJI                              Fiji      0.866667
# 17  KAZ                        Kazakhstan      0.866667
# 14  IND                             India      0.866667
# 15  IDN                         Indonesia      0.866667
# 16  JPN                             Japan      0.866667
# 45  VUT                           Vanuatu      0.866667
# 21  MYS                          Malaysia      0.866667
# 41  TON                             Tonga      0.866667
# 20  LAO  Lao People's Democratic Republic      0.933333
# 31  PNG                  Papua New Guinea      0.933333
# 10  FSM   Micronesia, Federated States of      0.933333
# 8   KHM                          Cambodia      0.933333
# 35  WSM                             Samoa      0.933333
# 36  SLB                   Solomon Islands      0.933333
# 22  MDV                          Maldives      0.933333
# 1   AFG                       Afghanistan      0.933333
# 25  MMR                           Myanmar      0.933333
# 40  TLS                       Timor-Leste      0.933333
# 44  UZB                        Uzbekistan      0.933333
# 6   BTN                            Bhutan      0.933333
# 0   NPL                             Nepal      1.000000
# 29  PAK                          Pakistan      1.000000
# 19  KGZ                        Kyrgyzstan      1.000000
# 5   BGD                        Bangladesh      1.000000
# 38  TJK                        Tajikistan      1.000000
# 24  MNG                          Mongolia      1.000000
#
#     value.Control of Corruption: Estimate  \
# 48                                  False
# 28                                   True
# 47                                  False
# 9                                    True
# 43                                   True
# 26                                   True
# 7                                    True
# 18                                   True
# 13                                   True
# 30                                   True
# 27                                   True
# 23                                   True
# 42                                   True
# 4                                    True
# 46                                   True
# 39                                   True
# 37                                   True
# 34                                   True
# 33                                   True
# 32                                   True
# 2                                    True
# 3                                    True
# 12                                   True
# 11                                   True
# 17                                   True
# 14                                   True
# 15                                   True
# 16                                   True
# 45                                   True
# 21                                   True
# 41                                   True
# 20                                   True
# 31                                   True
# 10                                   True
# 8                                    True
# 35                                   True
# 36                                   True
# 22                                   True
# 1                                    True
# 25                                   True
# 40                                   True
# 44                                   True
# 6                                    True
# 0                                    True
# 29                                   True
# 19                                   True
# 5                                    True
# 38                                   True
# 24                                   True
#
#     value.Government Effectiveness: Estimate  value.Rule of Law: Estimate  \
# 48                                     False                        False
# 28                                      True                         True
# 47                                     False                        False
# 9                                       True                         True
# 43                                      True                         True
# 26                                      True                         True
# 7                                       True                         True
# 18                                      True                         True
# 13                                      True                         True
# 30                                      True                         True
# 27                                      True                         True
# 23                                      True                         True
# 42                                      True                         True
# 4                                       True                         True
# 46                                      True                         True
# 39                                      True                         True
# 37                                      True                         True
# 34                                      True                         True
# 33                                      True                         True
# 32                                      True                         True
# 2                                       True                         True
# 3                                       True                         True
# 12                                      True                         True
# 11                                      True                         True
# 17                                      True                         True
# 14                                      True                         True
# 15                                      True                         True
# 16                                      True                         True
# 45                                      True                         True
# 21                                      True                         True
# 41                                      True                         True
# 20                                      True                         True
# 31                                      True                         True
# 10                                      True                         True
# 8                                       True                         True
# 35                                      True                         True
# 36                                      True                         True
# 22                                      True                         True
# 1                                       True                         True
# 25                                      True                         True
# 40                                      True                         True
# 44                                      True                         True
# 6                                       True                         True
# 0                                       True                         True
# 29                                      True                         True
# 19                                      True                         True
# 5                                       True                         True
# 38                                      True                         True
# 24                                      True                         True
#
#     conflict_stock_displacement_raw  disaster_stock_displacementr_raw   AIR  \
# 48                             True                              True  True
# 28                            False                             False  True
# 47                            False                             False  True
# 9                              True                              True  True
# 43                             True                              True  True
# 26                            False                             False  True
# 7                              True                              True  True
# 18                             True                              True  True
# 13                             True                              True  True
# 30                             True                              True  True
# 27                             True                              True  True
# 23                             True                              True  True
# 42                             True                              True  True
# 4                              True                              True  True
# 46                             True                              True  True
# 39                             True                              True  True
# 37                             True                              True  True
# 34                             True                              True  True
# 33                             True                              True  True
# 32                             True                              True  True
# 2                              True                              True  True
# 3                              True                              True  True
# 12                             True                              True  True
# 11                             True                              True  True
# 17                             True                              True  True
# 14                             True                              True  True
# 15                             True                              True  True
# 16                             True                              True  True
# 45                             True                              True  True
# 21                             True                              True  True
# 41                             True                              True  True
# 20                             True                              True  True
# 31                             True                              True  True
# 10                             True                              True  True
# 8                              True                              True  True
# 35                             True                              True  True
# 36                             True                              True  True
# 22                             True                              True  True
# 1                              True                              True  True
# 25                             True                              True  True
# 40                             True                              True  True
# 44                             True                              True  True
# 6                              True                              True  True
# 0                              True                              True  True
# 29                             True                              True  True
# 19                             True                              True  True
# 5                              True                              True  True
# 38                             True                              True  True
# 24                             True                              True  True
#
#       CCH  ims_both_sex  \
# 48   True         False
# 28  False          True
# 47   True          True
# 9   False          True
# 43  False         False
# 26  False          True
# 7    True          True
# 18   True          True
# 13   True          True
# 30   True          True
# 27   True          True
# 23   True          True
# 42   True          True
# 4    True          True
# 46   True          True
# 39   True          True
# 37   True          True
# 34   True          True
# 33   True          True
# 32   True          True
# 2    True          True
# 3    True          True
# 12   True          True
# 11   True          True
# 17   True          True
# 14   True          True
# 15   True          True
# 16   True          True
# 45   True          True
# 21   True          True
# 41   True          True
# 20   True          True
# 31   True          True
# 10   True          True
# 8    True          True
# 35   True          True
# 36   True          True
# 22   True          True
# 1    True          True
# 25   True          True
# 40   True          True
# 44   True          True
# 6    True          True
# 0    True          True
# 29   True          True
# 19   True          True
# 5    True          True
# 38   True          True
# 24   True          True
#
#     estimated_refugee_stock_incl_asylum_seekers_both_sexes  \
# 48                                              False
# 28                                              False
# 47                                              False
# 9                                               False
# 43                                              False
# 26                                               True
# 7                                               False
# 18                                              False
# 13                                               True
# 30                                              False
# 27                                               True
# 23                                              False
# 42                                               True
# 4                                                True
# 46                                              False
# 39                                               True
# 37                                               True
# 34                                               True
# 33                                               True
# 32                                               True
# 2                                                True
# 3                                                True
# 12                                               True
# 11                                               True
# 17                                               True
# 14                                               True
# 15                                               True
# 16                                               True
# 45                                              False
# 21                                               True
# 41                                              False
# 20                                              False
# 31                                               True
# 10                                              False
# 8                                                True
# 35                                              False
# 36                                              False
# 22                                              False
# 1                                                True
# 25                                              False
# 40                                              False
# 44                                               True
# 6                                               False
# 0                                                True
# 29                                               True
# 19                                               True
# 5                                                True
# 38                                               True
# 24                                               True
#
#     GDP per capita (constant 2015 US$)    D12  D_avg  hdi_value  \
# 48                               False  False  False      False
# 28                               False  False  False      False
# 47                                True  False  False       True
# 9                                False  False  False      False
# 43                                True   True   True      False
# 26                                True   True   True      False
# 7                                 True  False  False       True
# 18                                True   True   True      False
# 13                                True  False  False       True
# 30                                True   True   True       True
# 27                                True  False  False       True
# 23                                True   True   True       True
# 42                                True  False  False       True
# 4                                 True  False  False       True
# 46                                True  False  False       True
# 39                                True  False  False       True
# 37                                True  False  False       True
# 34                                True  False  False       True
# 33                                True  False  False       True
# 32                                True  False  False       True
# 2                                 True  False  False       True
# 3                                 True  False  False       True
# 12                                True  False  False       True
# 11                                True  False  False       True
# 17                                True  False  False       True
# 14                                True  False  False       True
# 15                                True  False  False       True
# 16                                True  False  False       True
# 45                                True   True   True       True
# 21                                True  False  False       True
# 41                                True   True   True       True
# 20                                True   True   True       True
# 31                                True   True   True       True
# 10                                True   True   True       True
# 8                                 True   True   True       True
# 35                                True   True   True       True
# 36                                True   True   True       True
# 22                                True   True   True       True
# 1                                 True   True   True       True
# 25                                True   True   True       True
# 40                                True   True   True       True
# 44                                True   True   True       True
# 6                                 True   True   True       True
# 0                                 True   True   True       True
# 29                                True   True   True       True
# 19                                True   True   True       True
# 5                                 True   True   True       True
# 38                                True   True   True       True
# 24                                True   True   True       True
#
#     value.Gini index (World Bank estimate)  P1: State Legitimacy
# 48                                   False                 False
# 28                                   False                 False
# 47                                   False                  True
# 9                                    False                 False
# 43                                    True                 False
# 26                                    True                 False
# 7                                    False                  True
# 18                                   False                 False
# 13                                   False                 False
# 30                                   False                 False
# 27                                   False                  True
# 23                                   False                 False
# 42                                   False                  True
# 4                                    False                  True
# 46                                    True                  True
# 39                                    True                  True
# 37                                    True                  True
# 34                                    True                  True
# 33                                    True                  True
# 32                                    True                  True
# 2                                     True                  True
# 3                                     True                  True
# 12                                    True                  True
# 11                                    True                  True
# 17                                    True                  True
# 14                                    True                  True
# 15                                    True                  True
# 16                                    True                  True
# 45                                    True                 False
# 21                                    True                  True
# 41                                    True                 False
# 20                                    True                  True
# 31                                   False                  True
# 10                                    True                  True
# 8                                    False                  True
# 35                                    True                  True
# 36                                    True                  True
# 22                                    True                  True
# 1                                    False                  True
# 25                                    True                  True
# 40                                    True                  True
# 44                                   False                  True
# 6                                     True                  True
# 0                                     True                  True
# 29                                    True                  True
# 19                                    True                  True
# 5                                     True                  True
# 38                                    True                  True
# 24                                    True                  True

# %% [markdown]
# ## Get Coverage by Indicator

# %%
missing = list(missing_df.iloc[:, 3:].sum(axis=0) / missing_df.iloc[:, 2:].shape[0])
missing = [[i] for i in missing]
missing_cols = pd.DataFrame((dict(zip(list(missing_df.columns)[3:], missing ))))
missing_cols = missing_cols.T.reset_index()
missing_cols.columns = ['variable', 'coverage']
missing_cols
# Out:
#                                              variable  coverage
# 0               value.Control of Corruption: Estimate  0.959184
# 1            value.Government Effectiveness: Estimate  0.959184
# 2                         value.Rule of Law: Estimate  0.959184
# 3                     conflict_stock_displacement_raw  0.938776
# 4                    disaster_stock_displacementr_raw  0.938776
# 5                                                 AIR  1.000000
# 6                                                 CCH  0.918367
# 7                                        ims_both_sex  0.959184
# 8   estimated_refugee_stock_incl_asylum_seekers_bo...  0.591837
# 9                  GDP per capita (constant 2015 US$)  0.938776
# 10                                                D12  0.510204
# 11                                              D_avg  0.510204
# 12                                          hdi_value  0.877551
# 13             value.Gini index (World Bank estimate)  0.673469
# 14                               P1: State Legitimacy  0.775510

# %% [markdown]
# ## Save Data

# %%
df.to_csv('data/cleaned-datasets/final/merged_data.csv', index=False)
first_df.to_csv('data/cleaned-datasets/final/small_data.csv', index=False)
imputed_df.to_csv('data/cleaned-datasets/final/small_data_imputed.csv', index=False)
missing_cols.to_csv('data/cleaned-datasets/final/indicator_coverage.csv', index=False)
missing_df.to_csv('data/cleaned-datasets/final/country_coverage.csv', index=False)
